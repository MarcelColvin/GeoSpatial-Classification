# %%
import shapefile
from collections import Counter

# %%
sf = shapefile.Reader('Crops_2016/2016_Crops.dbf')

# %%
shapes = sf.shapes()

# %%
fields =sf.fields

# %%
records = sf.records()

# %%
totalcropfields = [records[i][-5] for i in range(len(records))]

# %%
import re
try:
    m = re.search('^([^,]+),',totalcropfields[397])
except:
    m.group(0)

# %%
q= re.search('.*',totalcropfields[1])
a = []

# %%
finalcrops = []
for i in range(len(totalcropfields)):
    m = re.search('^([^,]+)[^,]',totalcropfields[i])
    if m is None:
        m = re.search('.*',totalcropfields[i])
    finalcrops.append(m.group(0))
    if m is None:
        finalcrops.append('')
for i in range(len(finalcrops)):
    finalcrops[i] = re.sub('ORG ','',finalcrops[i])
for i in range(len(finalcrops)):
    finalcrops[i] = re.sub(' FOR/FOD','',finalcrops[i])

# %%
construct = Counter(finalcrops)

# %%
keys = construct.keys()

# %%
import pandas as pd
cropList = construct
cropFamily = pd.DataFrame.from_dict(cropList, orient='index').reset_index()
cropFamily.columns = 'Crop','Count'
cropNames = cropFamily['Crop']
genus = ['Avena','Medicago','Carthamus','Triticum','Vitis','Prunus','Juglans','NaN','Fumigate','Solanum','Helianthus','Prunus',
        'NaN','Prunus','Prunus','Malus','NaN','Graze','Graze','Citrus','Olea','Pistacia','Prunus','Cucurbita','Ficus',
        'Solanum','NaN','Oryza','NaN','Pyrus','Beehive','Fumigate','NaN','Allium','Glycine','Zea','Cucurbita','Cucumis',
        'Turf','Castanea','Graze','Turf','Lolium','Flowering','Cucumis','Asparagus','Allium','Industrial','Hay','Carya','NaN',
        'NaN','Ocimum','Ocimum','Solanum','Citrus','Bean','Flowering','Vaccinium','Avena','Triticum','Sorghum','Tree',
        'Zea','Turf','GrnHouse Transplanting','GrnHouse Transplanting','Allium','Helianthus','Poaceae','Taraxacum',
        'NaN','NaN','NaN','Phaseolus','Cucumis','Carthamus','Prunus','Cucumis','Diospyros','NaN','Prunus','Hordeum',
        'Brassica','Daucus','Allium','Allium','Dennettia','Carya','Daucus','Brassica','Ditch','Citrullus','Cucurbita',
        'Triticum','Coriandrum','NaN','Lactuca','Prunus','Capsicum','Allium','Lactuca','Brassica','Brassica','Phaseolus',
        'Brassica','Punica','Lolium','Fumigate','Dactylis','Medicago','Cucumis','Punica','Actinidia','Sorghum','Zea',
        'Rosa','Beta','NaN','Solanum','NaN','Fragaria','NaN','Rubus','Solanum','NaN','Capsicum','Humulus','Secale',
        'Cicer','Sorghum','Vitis','Zizania','Citrullus','Cannabis','Vicia','Cucurbita','Cucumis','Cucurbita','Cucurbita','Cucurbita']
cropGenus = pd.DataFrame(cropFamily,genus)
#cropGenus.columns = 'Crop','Genus'
cropFamily['Genus'] = genus
# Out:
#                  Crop  Count       Genus
# 0                 OAT    338       Avena
# 1             ALFALFA   1541    Medicago
# 2           SAFFLOWER    348   Carthamus
# 3               WHEAT   1323    Triticum
# 4               GRAPE    676       Vitis
# 5               PRUNE     62      Prunus
# 6              WALNUT    600     Juglans
# 7     UNCULTIVATED AG   1444         NaN
# 8      COMM. FUMIGATN    148    Fumigate
# 9      TOMATO PROCESS   1702     Solanum
# 10     SUNFLOWER SEED   1216  Helianthus
# 11             ALMOND   1099      Prunus
# 12                      1021         NaN
# 13              PEACH     13      Prunus
# 14            APRICOT     12      Prunus
# 15              APPLE     18       Malus
# 16       UNCUL NON-AG    118         NaN
# 17        PASTURELAND    270       Graze
# 18          RANGELAND    181       Graze
# 19             CITRUS     34      Citrus
# 20              OLIVE     76        Olea
# 21          PISTACHIO    142    Pistacia
# 22               PLUM      2      Prunus
# 23             SQUASH     67   Cucurbita
# 24                FIG      6       Ficus
# 25             TOMATO     55     Solanum
# 26     VEGETBLE FRTNG     27         NaN
# 27               RICE    773       Oryza
# 28     LANDSCAPE MAIN      8         NaN
# 29               PEAR     15       Pyrus
# ..                ...    ...         ...
# 111    HONEYDEW MELON      4     Cucumis
# 112       POMEGRANATE      8      Punica
# 113              KIWI      1   Actinidia
# 114        SUDANGRASS     18     Sorghum
# 115         CORN SEED     25         Zea
# 116           OT-ROSE      9        Rosa
# 117              BEET      1        Beta
# 118  Rotational Crops      6         NaN
# 119       TOMATO SEED      5     Solanum
# 120     RESEARCH/PARK      3         NaN
# 121        STRAWBERRY      3    Fragaria
# 122    VEGETABLE FRTG      2         NaN
# 123        BLACKBERRY      2       Rubus
# 124          EGGPLANT      1     Solanum
# 125   N-OUTDR FLOWERS      2         NaN
# 126   PEPPER FRUITING      1    Capsicum
# 127              HOPS      1     Humulus
# 128               RYE      1      Secale
# 129     GARBANZO BEAN      1       Cicer
# 130           SORGHUM      8     Sorghum
# 131           OT-VINE      1       Vitis
# 132         WILD RICE     24     Zizania
# 133   WATERMELON SEED      4   Citrullus
# 134     HEMP/CANNABIS     81    Cannabis
# 135             VETCH      2       Vicia
# 136      PUMPKIN SEED      2   Cucurbita
# 137     CUCUMBER SEED      4     Cucumis
# 138     SQUASH WINTER      8   Cucurbita
# 139     SQUASH SUMMER      1   Cucurbita
# 140          ZUCCHINI      1   Cucurbita
#
# [141 rows x 3 columns]

# %%
values = []
for crop in cropNames:
    values.append(crop)
len(values)
# Out:
# 141
