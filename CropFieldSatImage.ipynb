# %%
band2 = 'Desktop/shared/S2A_OPER_PRD_MSIL1C_PDMC_20160715T044318_R113_V20160714T190130_20160714T190130.SAFE/GRANULE/S2A_OPER_MSI_L1C_TL_MPS__20160714T235020_A005544_T10SEJ_N02.04/IMG_DATA/EJ_B02.jp2'

# %%
import rasterio
import rasterio.features
import rasterio.warp
import rasterio.plot
from rasterio.mask import mask
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd

# %%
newcrop = rasterio.open(band2)

# %%
cropshape = gpd.read_file('GeoSpatial-Classification/Crops_2016/Crops_2016_26910.shp')
cropshape.crs = {"init": 'epsg:26910'}
cropshape = cropshape.to_crs('+proj=utm +zone=10 +ellps=WGS84 +datum=WGS84 +units=m +no_defs')
cropshape.crs
# Out:
# '+proj=utm +zone=10 +ellps=WGS84 +datum=WGS84 +units=m +no_defs'

# %%
newcr = cropshape.crop_list

# %%
onecrop = cropshape[cropshape.OBJECTID == 2965866

# %%
band2real.close()

# %%
fig,ax = plt.subplots(1,figsize=(7,7))
bounds = rasterio.plot.plotting_extent(newcrop)
rasterio.plot.show(newcrop,with_bounds=True, extent = bounds, ax=ax)
onecrop.plot(ax = ax,color = 'red')

# %%
trust = newcrop.read()
tr
# Out:
# array([[[1075, 1045, 1004, ...,  876,  876,  885],
#         [1051, 1015,  984, ...,  868,  861,  867],
#         [1077, 1065, 1060, ...,  866,  866,  864],
#         ...,
#         [ 890,  901,  912, ...,  783,  807,  842],
#         [ 885,  901,  911, ...,  807,  792,  830],
#         [ 908,  893,  899, ...,  790,  773,  828]]], dtype=uint16)

# %%
geom = onecrop.geometry.values[0]
from shapely.geometry import mapping
geoms = [mapping(geom)]

# %%
with rasterio.open(band2) as src:
    out_image, out_transform = mask(src,geoms,crop = True)

# %%
onecrop.geometry.values[0]

# %%
from osgeo import gdal

# %%
import os
os.system(command)
# Out:
# 0

# %%
cropshape.shape
# Out:
# (15359, 25)

# %%
command = "gdalwarp -te 594157.838929 4305840 594994.310086 4306598 -te_srs EPSG:32610 -t_srs EPSG:32610 mosaic2.tif Onecrop.tif"

# %%
import os
newi = i[-10:]
cmd = 'gdalwarp -te 609780 4240020 594994 4306598  -te_srs EPSG:32610 -t_srs EPSG:32610'
f = i + ' '  + newi
fincmd = cmd + ' ' + f
    #os.system(fincmd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-fe7f784d62c1> in <module>()
#       1 import os
# ----> 2 newi = i[-10:]
#       3 cmd = 'gdalwarp -te 609780 4240020 594994 4306598  -te_srs EPSG:32610 -t_srs EPSG:32610'
#       4 f = i + ' '  + newi
#       5 fincmd = cmd + ' ' + f
#
# NameError: name 'i' is not defined
