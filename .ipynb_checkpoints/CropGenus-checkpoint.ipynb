# %%
import shapefile

# %%
# %ls
# Out:
#  Volume in drive C is OS_Install
#  Volume Serial Number is F05F-E1DD
#
#  Directory of C:\Users\marce\Documents\PythonProjects\Sta160\GeoSpatial-Classification
#
# 06/03/2018  02:26 PM    <DIR>          .
# 06/03/2018  02:26 PM    <DIR>          ..
# 05/31/2018  02:17 PM    <DIR>          .ipynb_checkpoints
# 05/31/2018  02:15 PM             6,991 .Rhistory
# 05/02/2018  08:17 PM    <DIR>          cb_2016_us_county_500k
# 06/03/2018  02:26 PM         1,156,610 Clustering Fallow vs NonFallow.ipynb
# 05/30/2018  03:18 PM             1,162 Color_Expedition.R
# 05/29/2018  10:48 AM        13,155,527 ColorbandsDF.csv
# 05/29/2018  10:59 AM            10,821 Convoluted Shapefile, Crop Extracter.ipynb
# 05/29/2018  10:59 AM         3,090,121 Cropattempt2.ipynb
# 05/29/2018  10:48 AM            51,874 CropFieldSatImage.ipynb
# 05/29/2018  10:48 AM            26,111 CropGenus.ipynb
# 05/16/2018  11:40 AM    <DIR>          Crops_2016
# 06/01/2018  01:15 PM         6,343,084 Cultivatedfields.csv
# 05/30/2018  03:18 PM           104,622 DFmaker.ipynb
# 05/21/2018  10:09 AM           314,320 Extract_fields.ipynb
# 05/14/2018  08:32 PM         1,913,192 Extract_fields_data_FIx_pictures.ipynb
# 05/16/2018  11:51 AM         1,886,420 Extract_fields_dataBradysfile.ipynb
# 06/01/2018  01:23 PM         6,350,782 fullcultivate.csv
# 05/29/2018  10:48 AM             3,055 MakeColorBands.ipynb
# 06/01/2018  12:40 PM           192,971 MakingtheClass.ipynb
# 05/13/2018  05:47 PM           495,593 NOT_RELEVANT_Data_resizing_and_extracting.ipynb
# 05/14/2018  01:56 PM           380,787 NOT_RELEVANT_Marcel_Reproject_image.ipynb
# 06/03/2018  12:56 PM             2,312 OrgvNonOrg.R
# 05/14/2018  07:49 PM    <DIR>          pictures
# 05/14/2018  02:07 PM           163,284 PixelBoxBrady.ipynb
# 06/03/2018  12:56 PM         9,149,517 predictedcrop.csv
# 05/14/2018  08:32 PM            14,125 SEMI_RELEVANT_learning_to_georeference.ipynb
# 05/03/2018  02:44 PM             1,953 Terminal tester.ipynb
# 05/14/2018  02:07 PM               133 todo.txt
# 06/03/2018  12:56 PM         1,244,264 unkownvuncult.csv
# 05/30/2018  03:18 PM        17,700,470 updateddf.csv
# 05/31/2018  03:39 PM             3,326 violinPlot_bands.R
# 05/29/2018  10:48 AM         4,153,580 Yolocropper.ipynb
# 05/29/2018  10:48 AM         4,425,593 Yolocropper_deprecated.ipynb
#               29 File(s)     72,342,600 bytes
#                6 Dir(s)  32,006,840,320 bytes free

# %%
sf = shapefile.Reader('Crops_2016/2016_Crops.dbf')

# %%
shapes = sf.shapes()

# %%
fields =sf.fields

# %%
records = sf.records()

# %%
totalcropfields = [records[i][-5] for i in range(len(records))]

# %%
from collections import Counter

# %%
import re
try:
    m = re.search('^([^,]+),',totalcropfields[397])
except:
    m.group(0)

# %%
q= re.search('.*',totalcropfields[1])
a = []

# %%
finalcrops = []
for i in range(len(totalcropfields)):
    m = re.search('^([^,]+)[^,]',totalcropfields[i])
    if m is None:
        m = re.search('.*',totalcropfields[i])
    finalcrops.append(m.group(0))
    if m is None:
        finalcrops.append('')
for i in range(len(finalcrops)):
    finalcrops[i] = re.sub('ORG ','',finalcrops[i])
for i in range(len(finalcrops)):
    finalcrops[i] = re.sub(' FOR/FOD','',finalcrops[i])

# %%
construct = Counter(finalcrops)

# %%
keys = construct.keys()

# %%
import pandas as pd
cropList = construct
cropFamily = pd.DataFrame.from_dict(cropList, orient='index').reset_index()
cropFamily.columns = 'Crop','Count'

cropNames = cropFamily['Crop']


genus = ['Avena','Medicago','Carthamus','Triticum','Vitis','Prunus','Juglans','NaN','Fumigate','Solanum','Helianthus','Prunus',
        'NaN','Prunus','Prunus','Malus','NaN','Graze','Graze','Citrus','Olea','Pistacia','Prunus','Cucurbita','Ficus',
        'Solanum','NaN','Oryza','NaN','Pyrus','Beehive','Fumigate','NaN','Allium','Glycine','Zea','Cucurbita','Cucumis',
        'Turf','Castanea','Graze','Turf','Lolium','Flowering','Cucumis','Asparagus','Allium','Industrial','Hay','Carya','NaN',
        'NaN','Ocimum','Ocimum','Solanum','Citrus','Bean','Flowering','Vaccinium','Avena','Triticum','Sorghum','Tree',
        'Zea','Turf','GrnHouse Transplanting','GrnHouse Transplanting','Allium','Helianthus','Poaceae','Taraxacum',
        'NaN','NaN','NaN','Phaseolus','Cucumis','Carthamus','Prunus','Cucumis','Diospyros','NaN','Prunus','Hordeum',
        'Brassica','Daucus','Allium','Allium','Dennettia','Carya','Daucus','Brassica','Ditch','Citrullus','Cucurbita',
        'Triticum','Coriandrum','NaN','Lactuca','Prunus','Capsicum','Allium','Lactuca','Brassica','Brassica','Phaseolus',
        'Brassica','Punica','Lolium','Fumigate','Dactylis','Medicago','Cucumis','Punica','Actinidia','Sorghum','Zea',
        'Rosa','Beta','NaN','Solanum','NaN','Fragaria','NaN','Rubus','Solanum','NaN','Capsicum','Humulus','Secale',
        'Cicer','Sorghum','Vitis','Zizania','Citrullus','Cannabis','Vicia','Cucurbita','Cucumis','Cucurbita','Cucurbita','Cucurbita']
cropGenus = pd.DataFrame(cropFamily,genus)
#cropGenus.columns = 'Crop','Genus'

cropFamily['Genus'] = genus

# %%
len(genus)
# Out:
# 141

# %%
values = []
for crop in cropNames:
    values.append(crop)

len(values)
# Out:
# 141

# %%
cropFamily.sort_values('Count', ascending = False)
# Out:
#                     Crop  Count                   Genus
# 9         TOMATO PROCESS   1702                 Solanum
# 1                ALFALFA   1541                Medicago
# 7        UNCULTIVATED AG   1444                     NaN
# 3                  WHEAT   1323                Triticum
# 10        SUNFLOWER SEED   1216              Helianthus
# 11                ALMOND   1099                  Prunus
# 12                         1021                     NaN
# 27                  RICE    773                   Oryza
# 4                  GRAPE    676                   Vitis
# 6                 WALNUT    600                 Juglans
# 35                  CORN    355                     Zea
# 2              SAFFLOWER    348               Carthamus
# 0                    OAT    338                   Avena
# 17           PASTURELAND    270                   Graze
# 18             RANGELAND    181                   Graze
# 8         COMM. FUMIGATN    148                Fumigate
# 21             PISTACHIO    142                Pistacia
# 32       RESEARCH COMMOD    123                     NaN
# 42               RYEGRAS    120                  Lolium
# 16          UNCUL NON-AG    118                     NaN
# 54     TOMATO PROCESSING    101                 Solanum
# 48       FORAGE HAY/SLGE     89                     Hay
# 67                GARLIC     81                  Allium
# 134        HEMP/CANNABIS     81                Cannabis
# 20                 OLIVE     76                    Olea
# 33            ONION SEED     75                  Allium
# 23                SQUASH     67               Cucurbita
# 5                  PRUNE     62                  Prunus
# 25                TOMATO     55                 Solanum
# 90          CABBAGE SEED     50                Brassica
# ..                   ...    ...                     ...
# 22                  PLUM      2                  Prunus
# 136         PUMPKIN SEED      2               Cucurbita
# 66   ORG-N-GRNHS TRANSPT      2  GrnHouse Transplanting
# 135                VETCH      2                   Vicia
# 56             BEAN UNSP      2                    Bean
# 98             NECTARINE      2                  Prunus
# 47       INDUSTRIAL SITE      2              Industrial
# 91                 DITCH      2                   Ditch
# 125      N-OUTDR FLOWERS      2                     NaN
# 131              OT-VINE      1                   Vitis
# 129        GARBANZO BEAN      1                   Cicer
# 139        SQUASH SUMMER      1               Cucurbita
# 128                  RYE      1                  Secale
# 126      PEPPER FRUITING      1                Capsicum
# 127                 HOPS      1                 Humulus
# 105              MUSTARD      1                Brassica
# 124             EGGPLANT      1                 Solanum
# 117                 BEET      1                    Beta
# 113                 KIWI      1               Actinidia
# 39              CHESTNUT      1                Castanea
# 108      SOIL FUM/PREPLT      1                Fumigate
# 106           POME FRUIT      1                  Punica
# 46             ONION DRY      1                  Allium
# 88                  NUTS      1                   Carya
# 57       GP-FLWRNG PLANT      1               Flowering
# 79             PERSIMMON      1               Diospyros
# 58             BLUEBERRY      1               Vaccinium
# 65       N-GRNHS TRANSPL      1  GrnHouse Transplanting
# 73          GP-DEC. TREE      1                     NaN
# 140             ZUCCHINI      1               Cucurbita
#
# [141 rows x 3 columns]

# %%
cropFamily
# Out:
#                  Crop  Count       Genus
# 0                 OAT    338       Avena
# 1             ALFALFA   1541    Medicago
# 2           SAFFLOWER    348   Carthamus
# 3               WHEAT   1323    Triticum
# 4               GRAPE    676       Vitis
# 5               PRUNE     62      Prunus
# 6              WALNUT    600     Juglans
# 7     UNCULTIVATED AG   1444         NaN
# 8      COMM. FUMIGATN    148    Fumigate
# 9      TOMATO PROCESS   1702     Solanum
# 10     SUNFLOWER SEED   1216  Helianthus
# 11             ALMOND   1099      Prunus
# 12                      1021         NaN
# 13              PEACH     13      Prunus
# 14            APRICOT     12      Prunus
# 15              APPLE     18       Malus
# 16       UNCUL NON-AG    118         NaN
# 17        PASTURELAND    270       Graze
# 18          RANGELAND    181       Graze
# 19             CITRUS     34      Citrus
# 20              OLIVE     76        Olea
# 21          PISTACHIO    142    Pistacia
# 22               PLUM      2      Prunus
# 23             SQUASH     67   Cucurbita
# 24                FIG      6       Ficus
# 25             TOMATO     55     Solanum
# 26     VEGETBLE FRTNG     27         NaN
# 27               RICE    773       Oryza
# 28     LANDSCAPE MAIN      8         NaN
# 29               PEAR     15       Pyrus
# ..                ...    ...         ...
# 111    HONEYDEW MELON      4     Cucumis
# 112       POMEGRANATE      8      Punica
# 113              KIWI      1   Actinidia
# 114        SUDANGRASS     18     Sorghum
# 115         CORN SEED     25         Zea
# 116           OT-ROSE      9        Rosa
# 117              BEET      1        Beta
# 118  Rotational Crops      6         NaN
# 119       TOMATO SEED      5     Solanum
# 120     RESEARCH/PARK      3         NaN
# 121        STRAWBERRY      3    Fragaria
# 122    VEGETABLE FRTG      2         NaN
# 123        BLACKBERRY      2       Rubus
# 124          EGGPLANT      1     Solanum
# 125   N-OUTDR FLOWERS      2         NaN
# 126   PEPPER FRUITING      1    Capsicum
# 127              HOPS      1     Humulus
# 128               RYE      1      Secale
# 129     GARBANZO BEAN      1       Cicer
# 130           SORGHUM      8     Sorghum
# 131           OT-VINE      1       Vitis
# 132         WILD RICE     24     Zizania
# 133   WATERMELON SEED      4   Citrullus
# 134     HEMP/CANNABIS     81    Cannabis
# 135             VETCH      2       Vicia
# 136      PUMPKIN SEED      2   Cucurbita
# 137     CUCUMBER SEED      4     Cucumis
# 138     SQUASH WINTER      8   Cucurbita
# 139     SQUASH SUMMER      1   Cucurbita
# 140          ZUCCHINI      1   Cucurbita
#
# [141 rows x 3 columns]
